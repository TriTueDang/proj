# %% [markdown]
# # Srovnání detectorů obličeje

# %% [markdown]
# ### Import modulu

# %%
import time
from utk_loader import load_utkface_images
from utils.evaluation import evaluate
from sum_results import summarize_results
from detectors.mtcnn_detector import MTCNNDetector
from detectors.haar_detector import HaarCascadeDetector
from detectors.scrfd_detector import SCRFDDetector
from detectors.blazeface_detector import BlazeFaceDetector
# Out:
# c:\Users\Tue Dang Tri\AppData\Local\Programs\Python\Python312\Lib\site-packages\albumentations\check_version.py:147: UserWarning: Error fetching version info <urlopen error [Errno 11001] getaddrinfo failed>
#   data = fetch_version_info()

# %%
dataset = load_utkface_images("./images/UTKFace", max_images=23708)

# %% [markdown]
# ### OpenCV Haar detector

# %%
start_time = time.time()
print("Starting Haar Cascade evaluation...")
detector_haar = HaarCascadeDetector()
stats = evaluate(detector_haar, dataset)
# full result dataframe in results directory
summarize_results(stats, 'HAAR')
end_time = time.time()
print(f"Haar Cascade evaluation took {end_time - start_time:.2f} seconds.")
# Out:
# Starting Haar Cascade evaluation...
#
#  Detection Accuracy Summary:
#
#      Gender    Race AgeGroup  Accuracy (%)  Samples
# 28   Female   Asian       0s         17.20      436
# 2    Female   Asian     100s         25.00        4
# 12   Female   Asian      10s         72.88       59
# 20   Female   Asian     110s          0.00        1
# 38   Female   Asian      20s         65.53      969
# 48   Female   Asian      30s         70.40      250
# 58   Female   Asian      40s         70.73       41
# 68   Female   Asian      50s         79.17       24
# 78   Female   Asian      60s         53.33       15
# 87   Female   Asian      70s         50.00       14
# 96   Female   Asian      80s         55.56       27
# 106  Female   Asian      90s         36.84       19
# 27   Female   Black       0s         36.78       87
# 4    Female   Black     100s          0.00        1
# 11   Female   Black      10s         51.55       97
# 18   Female   Black     110s          0.00        2
# 37   Female   Black      20s         52.67      991
# 47   Female   Black      30s         54.63      637
# 57   Female   Black      40s         59.57      188
# 67   Female   Black      50s         60.40      101
# 77   Female   Black      60s         54.72       53
# 86   Female   Black      70s         41.67       24
# 95   Female   Black      80s         45.00       20
# 105  Female   Black      90s         28.57        7
# 29   Female  Indian       0s         29.43      265
# 13   Female  Indian      10s         74.16       89
# 19   Female  Indian     110s         50.00        2
# 39   Female  Indian      20s         69.66      870
# 49   Female  Indian      30s         72.41      261
# 59   Female  Indian      40s         85.06       87
# 69   Female  Indian      50s         61.25       80
# 79   Female  Indian      60s         67.74       31
# 88   Female  Indian      70s         53.85       13
# 97   Female  Indian      80s         40.00       15
# 107  Female  Indian      90s        100.00        1
# 30   Female   Other       0s         36.00      250
# 14   Female   Other      10s         81.37      102
# 40   Female   Other      20s         79.75      400
# 50   Female   Other      30s         79.39      131
# 60   Female   Other      40s         90.00       30
# 70   Female   Other      50s         70.00       10
# 80   Female   Other      60s         50.00        6
# 98   Female   Other      80s         33.33        3
# 26   Female   White       0s         37.26      577
# 1    Female   White     100s         22.22        9
# 10   Female   White      10s         82.31      503
# 17   Female   White     110s         66.67        6
# 36   Female   White      20s         71.39     1052
# 46   Female   White      30s         72.69      780
# 56   Female   White      40s         76.05      380
# 66   Female   White      50s         69.18      425
# 76   Female   White      60s         62.40      367
# 85   Female   White      70s         54.81      208
# 94   Female   White      80s         44.92      236
# 104  Female   White      90s         32.76       58
# 23     Male   Asian       0s          8.11      493
# 3      Male   Asian     100s          0.00        1
# 7      Male   Asian      10s         51.35       37
# 16     Male   Asian     110s          0.00        1
# 33     Male   Asian      20s         60.28      360
# 43     Male   Asian      30s         61.73      277
# 53     Male   Asian      40s         58.62      116
# 63     Male   Asian      50s         47.25       91
# 73     Male   Asian      60s         37.50       80
# 83     Male   Asian      70s         45.71       70
# 92     Male   Asian      80s         17.95       39
# 102    Male   Asian      90s         60.00       10
# 22     Male   Black       0s         20.90       67
# 6      Male   Black      10s         50.59       85
# 32     Male   Black      20s         51.33      867
# 42     Male   Black      30s         51.69      621
# 52     Male   Black      40s         54.27      234
# 62     Male   Black      50s         48.54      206
# 72     Male   Black      60s         47.95      146
# 82     Male   Black      70s         43.75       64
# 91     Male   Black      80s         23.81       21
# 101    Male   Black      90s         57.14        7
# 24     Male  Indian       0s         18.75      224
# 8      Male  Indian      10s         71.67       60
# 34     Male  Indian      20s         61.84      629
# 44     Male  Indian      30s         61.39      461
# 54     Male  Indian      40s         52.62      344
# 64     Male  Indian      50s         53.76      372
# 74     Male  Indian      60s         49.61      129
# 84     Male  Indian      70s         41.18       34
# 93     Male  Indian      80s         50.00        6
# 103    Male  Indian      90s          0.00        2
# 25     Male   Other       0s         23.13      134
# 9      Male   Other      10s         64.41       59
# 35     Male   Other      20s         58.46      272
# 45     Male   Other      30s         61.74      149
# 55     Male   Other      40s         66.67       90
# 65     Male   Other      50s         55.32       47
# 75     Male   Other      60s         16.67        6
# 89     Male   Other      70s         50.00        2
# 99     Male   Other      80s          0.00        1
# 21     Male   White       0s         30.62      529
# 0      Male   White     100s          0.00        4
# 5      Male   White      10s         61.14      440
# 15     Male   White     110s        100.00        1
# 31     Male   White      20s         59.10      934
# 41     Male   White      30s         59.96      969
# 51     Male   White      40s         60.27      735
# 61     Male   White      50s         59.81      943
# 71     Male   White      60s         53.42      483
# 81     Male   White      70s         43.70      270
# 90     Male   White      80s         43.38      136
# 100    Male   White      90s         36.36       33
# Haar Cascade evaluation took 252.07 seconds.

# %% [markdown]
# ### MTCNN detector

# %%
start_time = time.time()
print("Starting MTCNN evaluation...")
detector_mtcnn = MTCNNDetector()
stats = evaluate(detector_mtcnn, dataset)
# full result dataframe in results directory
summarize_results(stats, 'MTCNN')
end_time = time.time()
print(f"MTCNN evaluation took {end_time - start_time:.2f} seconds.")
# Out:
# Starting MTCNN evaluation...
#
#  Detection Accuracy Summary:
#
#      Gender    Race AgeGroup  Accuracy (%)  Samples
# 28   Female   Asian       0s         72.94      436
# 2    Female   Asian     100s         25.00        4
# 12   Female   Asian      10s         96.61       59
# 20   Female   Asian     110s        100.00        1
# 38   Female   Asian      20s         95.05      969
# 48   Female   Asian      30s         94.00      250
# 58   Female   Asian      40s         97.56       41
# 68   Female   Asian      50s         91.67       24
# 78   Female   Asian      60s        100.00       15
# 87   Female   Asian      70s         78.57       14
# 96   Female   Asian      80s         70.37       27
# 106  Female   Asian      90s         52.63       19
# 27   Female   Black       0s         78.16       87
# 4    Female   Black     100s          0.00        1
# 11   Female   Black      10s         77.32       97
# 18   Female   Black     110s         50.00        2
# 37   Female   Black      20s         81.84      991
# 47   Female   Black      30s         83.36      637
# 57   Female   Black      40s         82.45      188
# 67   Female   Black      50s         76.24      101
# 77   Female   Black      60s         67.92       53
# 86   Female   Black      70s         62.50       24
# 95   Female   Black      80s         65.00       20
# 105  Female   Black      90s         28.57        7
# 29   Female  Indian       0s         88.68      265
# 13   Female  Indian      10s         92.13       89
# 19   Female  Indian     110s         50.00        2
# 39   Female  Indian      20s         90.57      870
# 49   Female  Indian      30s         90.04      261
# 59   Female  Indian      40s         93.10       87
# 69   Female  Indian      50s         87.50       80
# 79   Female  Indian      60s         70.97       31
# 88   Female  Indian      70s         76.92       13
# 97   Female  Indian      80s         80.00       15
# 107  Female  Indian      90s        100.00        1
# 30   Female   Other       0s         84.40      250
# 14   Female   Other      10s         92.16      102
# 40   Female   Other      20s         97.00      400
# 50   Female   Other      30s         93.89      131
# 60   Female   Other      40s        100.00       30
# 70   Female   Other      50s         90.00       10
# 80   Female   Other      60s         66.67        6
# 98   Female   Other      80s         66.67        3
# 26   Female   White       0s         81.11      577
# 1    Female   White     100s         33.33        9
# 10   Female   White      10s         96.02      503
# 17   Female   White     110s         83.33        6
# 36   Female   White      20s         93.92     1052
# 46   Female   White      30s         94.74      780
# 56   Female   White      40s         91.58      380
# 66   Female   White      50s         90.35      425
# 76   Female   White      60s         88.01      367
# 85   Female   White      70s         78.37      208
# 94   Female   White      80s         74.15      236
# 104  Female   White      90s         60.34       58
# 23     Male   Asian       0s         63.29      493
# 3      Male   Asian     100s          0.00        1
# 7      Male   Asian      10s         81.08       37
# 16     Male   Asian     110s          0.00        1
# 33     Male   Asian      20s         88.89      360
# 43     Male   Asian      30s         88.09      277
# 53     Male   Asian      40s         87.93      116
# 63     Male   Asian      50s         82.42       91
# 73     Male   Asian      60s         82.50       80
# 83     Male   Asian      70s         75.71       70
# 92     Male   Asian      80s         69.23       39
# 102    Male   Asian      90s         40.00       10
# 22     Male   Black       0s         77.61       67
# 6      Male   Black      10s         89.41       85
# 32     Male   Black      20s         79.35      867
# 42     Male   Black      30s         75.52      621
# 52     Male   Black      40s         72.22      234
# 62     Male   Black      50s         70.39      206
# 72     Male   Black      60s         71.23      146
# 82     Male   Black      70s         53.12       64
# 91     Male   Black      80s         57.14       21
# 101    Male   Black      90s         71.43        7
# 24     Male  Indian       0s         79.91      224
# 8      Male  Indian      10s         85.00       60
# 34     Male  Indian      20s         85.06      629
# 44     Male  Indian      30s         85.25      461
# 54     Male  Indian      40s         77.62      344
# 64     Male  Indian      50s         75.81      372
# 74     Male  Indian      60s         75.19      129
# 84     Male  Indian      70s         67.65       34
# 93     Male  Indian      80s         33.33        6
# 103    Male  Indian      90s         50.00        2
# 25     Male   Other       0s         76.87      134
# 9      Male   Other      10s         89.83       59
# 35     Male   Other      20s         93.75      272
# 45     Male   Other      30s         93.96      149
# 55     Male   Other      40s         90.00       90
# 65     Male   Other      50s         78.72       47
# 75     Male   Other      60s         50.00        6
# 89     Male   Other      70s         50.00        2
# 99     Male   Other      80s          0.00        1
# 21     Male   White       0s         77.32      529
# 0      Male   White     100s         25.00        4
# 5      Male   White      10s         89.32      440
# 15     Male   White     110s        100.00        1
# 31     Male   White      20s         93.68      934
# 41     Male   White      30s         92.88      969
# 51     Male   White      40s         90.75      735
# 61     Male   White      50s         87.91      943
# 71     Male   White      60s         80.75      483
# 81     Male   White      70s         72.96      270
# 90     Male   White      80s         73.53      136
# 100    Male   White      90s         63.64       33
# MTCNN evaluation took 2638.35 seconds.

# %% [markdown]
# ### BLAZEFACE detector

# %%
start_time = time.time()
detector_blazeface = BlazeFaceDetector()
stats = evaluate(detector_blazeface, dataset)
# full result dataframe in results directory
summarize_results(stats, 'BLAZEFACE')
end_time = time.time()
print(f"Blazeface evaluation took {end_time - start_time:.2f} seconds.")
# Out:
#  Detection Accuracy Summary:
#
#      Gender    Race AgeGroup  Accuracy (%)  Samples
# 28   Female   Asian       0s         97.48      436
# 2    Female   Asian     100s        100.00        4
# 12   Female   Asian      10s        100.00       59
# 20   Female   Asian     110s        100.00        1
# 38   Female   Asian      20s         99.28      969
# 48   Female   Asian      30s         99.60      250
# 58   Female   Asian      40s        100.00       41
# 68   Female   Asian      50s        100.00       24
# 78   Female   Asian      60s        100.00       15
# 87   Female   Asian      70s        100.00       14
# 96   Female   Asian      80s         96.30       27
# 106  Female   Asian      90s        100.00       19
# 27   Female   Black       0s         96.55       87
# 4    Female   Black     100s        100.00        1
# 11   Female   Black      10s        100.00       97
# 18   Female   Black     110s        100.00        2
# 37   Female   Black      20s         98.79      991
# 47   Female   Black      30s         98.74      637
# 57   Female   Black      40s         98.40      188
# 67   Female   Black      50s         98.02      101
# 77   Female   Black      60s        100.00       53
# 86   Female   Black      70s         91.67       24
# 95   Female   Black      80s         95.00       20
# 105  Female   Black      90s        100.00        7
# 29   Female  Indian       0s         97.36      265
# 13   Female  Indian      10s        100.00       89
# 19   Female  Indian     110s        100.00        2
# 39   Female  Indian      20s         99.54      870
# 49   Female  Indian      30s        100.00      261
# 59   Female  Indian      40s        100.00       87
# 69   Female  Indian      50s        100.00       80
# 79   Female  Indian      60s         96.77       31
# 88   Female  Indian      70s        100.00       13
# 97   Female  Indian      80s        100.00       15
# 107  Female  Indian      90s        100.00        1
# 30   Female   Other       0s         98.00      250
# 14   Female   Other      10s        100.00      102
# 40   Female   Other      20s         99.75      400
# 50   Female   Other      30s         99.24      131
# 60   Female   Other      40s        100.00       30
# 70   Female   Other      50s        100.00       10
# 80   Female   Other      60s        100.00        6
# 98   Female   Other      80s        100.00        3
# 26   Female   White       0s         98.79      577
# 1    Female   White     100s        100.00        9
# 10   Female   White      10s         99.60      503
# 17   Female   White     110s         83.33        6
# 36   Female   White      20s         99.14     1052
# 46   Female   White      30s         99.62      780
# 56   Female   White      40s         98.95      380
# 66   Female   White      50s         99.29      425
# 76   Female   White      60s         99.18      367
# 85   Female   White      70s         99.52      208
# 94   Female   White      80s        100.00      236
# 104  Female   White      90s         94.83       58
# 23     Male   Asian       0s         96.96      493
# 3      Male   Asian     100s        100.00        1
# 7      Male   Asian      10s        100.00       37
# 16     Male   Asian     110s        100.00        1
# 33     Male   Asian      20s         99.44      360
# 43     Male   Asian      30s        100.00      277
# 53     Male   Asian      40s        100.00      116
# 63     Male   Asian      50s        100.00       91
# 73     Male   Asian      60s         96.25       80
# 83     Male   Asian      70s         98.57       70
# 92     Male   Asian      80s        100.00       39
# 102    Male   Asian      90s         90.00       10
# 22     Male   Black       0s        100.00       67
# 6      Male   Black      10s         98.82       85
# 32     Male   Black      20s         98.85      867
# 42     Male   Black      30s         98.71      621
# 52     Male   Black      40s         98.72      234
# 62     Male   Black      50s         98.54      206
# 72     Male   Black      60s         97.26      146
# 82     Male   Black      70s         96.88       64
# 91     Male   Black      80s         95.24       21
# 101    Male   Black      90s         57.14        7
# 24     Male  Indian       0s         96.88      224
# 8      Male  Indian      10s        100.00       60
# 34     Male  Indian      20s         98.57      629
# 44     Male  Indian      30s         98.92      461
# 54     Male  Indian      40s         96.80      344
# 64     Male  Indian      50s         98.12      372
# 74     Male  Indian      60s         98.45      129
# 84     Male  Indian      70s         97.06       34
# 93     Male  Indian      80s        100.00        6
# 103    Male  Indian      90s         50.00        2
# 25     Male   Other       0s         96.27      134
# 9      Male   Other      10s        100.00       59
# 35     Male   Other      20s         99.26      272
# 45     Male   Other      30s        100.00      149
# 55     Male   Other      40s        100.00       90
# 65     Male   Other      50s        100.00       47
# 75     Male   Other      60s         83.33        6
# 89     Male   Other      70s        100.00        2
# 99     Male   Other      80s        100.00        1
# 21     Male   White       0s         98.68      529
# 0      Male   White     100s        100.00        4
# 5      Male   White      10s         99.55      440
# 15     Male   White     110s        100.00        1
# 31     Male   White      20s         98.18      934
# 41     Male   White      30s         99.48      969
# 51     Male   White      40s         99.59      735
# 61     Male   White      50s         99.26      943
# 71     Male   White      60s         99.38      483
# 81     Male   White      70s         97.41      270
# 90     Male   White      80s         98.53      136
# 100    Male   White      90s         96.97       33
# Blazeface evaluation took 97.90 seconds.

# %% [markdown]
# ### SCRFD detector

# %%
dataset = load_utkface_images("./images/UTKFace", max_images=1000)

# %%
start_time = time.time()
detector_scrfd = SCRFDDetector()
print("Starting SCRFD evaluation...")
stats = evaluate(detector_scrfd, dataset)
# full result dataframe in results directory
summarize_results(stats, 'SCRFD')
end_time = time.time()
print(f"SCRFD evaluation took {end_time - start_time:.2f} seconds.")
# Out:
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Tue Dang Tri/.insightface\models\buffalo_l\1k3d68.onnx landmark_3d_68 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Tue Dang Tri/.insightface\models\buffalo_l\2d106det.onnx landmark_2d_106 ['None', 3, 192, 192] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Tue Dang Tri/.insightface\models\buffalo_l\det_10g.onnx detection [1, 3, '?', '?'] 127.5 128.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Tue Dang Tri/.insightface\models\buffalo_l\genderage.onnx genderage ['None', 3, 96, 96] 0.0 1.0
# Applied providers: ['CPUExecutionProvider'], with options: {'CPUExecutionProvider': {}}
# find model: C:\Users\Tue Dang Tri/.insightface\models\buffalo_l\w600k_r50.onnx recognition ['None', 3, 112, 112] 127.5 127.5
# set det-size: (160, 160)
# Starting SCRFD evaluation...
#
#  Detection Accuracy Summary:
#
#    Gender    Race AgeGroup  Accuracy (%)  Samples
# 2  Female   Asian     100s         100.0        4
# 4  Female   Black     100s         100.0        1
# 1  Female   White     100s         100.0        9
# 3    Male   Asian     100s         100.0        1
# 7    Male   Asian      10s         100.0        2
# 6    Male   Black      10s         100.0        8
# 8    Male  Indian      10s         100.0        4
# 9    Male   Other      10s         100.0        1
# 0    Male   White     100s         100.0        4
# 5    Male   White      10s         100.0       67
# SCRFD evaluation took 41.57 seconds.
